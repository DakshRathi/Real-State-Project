# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
import category_encoders as ce
from sklearn.svm import SVR
from sklearn.linear_model import Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from sklearn.decomposition import PCA

# %%
df = pd.read_csv('../Dataset/Processed/gurgaon_properties_post_feature_selection_v2.csv')

# %%
df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony   agePossession  \
# 0          flat   sector 36   0.82      3.0       2.0       2    New Property
# 1          flat   sector 89   0.95      2.0       2.0       2    New Property
# 2          flat  sohna road   0.32      2.0       2.0       1    New Property
# 3          flat   sector 92   1.60      3.0       4.0      3+  Relatively New
# 4          flat  sector 102   0.48      2.0       2.0       1  Relatively New
#
#    built_up_area  servant room  store room  furnishing_type luxury_category  \
# 0          850.0           0.0         0.0              0.0             Low
# 1         1226.0           1.0         0.0              0.0             Low
# 2         1000.0           0.0         0.0              0.0             Low
# 3         1615.0           1.0         0.0              1.0            High
# 4          582.0           0.0         1.0              0.0            High
#
#   floor_category
# 0      Low Floor
# 1      Mid Floor
# 2     High Floor
# 3      Mid Floor
# 4      Mid Floor

# %%
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# 0.0    2349
# 1.0    1018
# 2.0     187
# Name: count, dtype: int64

# %%
# 0 -> unfurnished
# 1 -> semifurnished
# 2 -> furnished
df['furnishing_type'] = df['furnishing_type'].replace({0.0:'unfurnished',1.0:'semifurnished',2.0:'furnished'})

# %%
df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony   agePossession  \
# 0          flat   sector 36   0.82      3.0       2.0       2    New Property
# 1          flat   sector 89   0.95      2.0       2.0       2    New Property
# 2          flat  sohna road   0.32      2.0       2.0       1    New Property
# 3          flat   sector 92   1.60      3.0       4.0      3+  Relatively New
# 4          flat  sector 102   0.48      2.0       2.0       1  Relatively New
#
#    built_up_area  servant room  store room furnishing_type luxury_category  \
# 0          850.0           0.0         0.0     unfurnished             Low
# 1         1226.0           1.0         0.0     unfurnished             Low
# 2         1000.0           0.0         0.0     unfurnished             Low
# 3         1615.0           1.0         0.0   semifurnished            High
# 4          582.0           0.0         1.0     unfurnished            High
#
#   floor_category
# 0      Low Floor
# 1      Mid Floor
# 2     High Floor
# 3      Mid Floor
# 4      Mid Floor

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
# Applying the log1p transformation to the target variable
y_transformed = np.log1p(y)

# %% [markdown]
# ### Ordinal Encoding

# %%
columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(), columns_to_encode)
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (np.float64(0.7363096633436828), np.float64(0.03238005754429936))

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# np.float64(0.9463822160089359)

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_output
# Out:
# [['linear_reg',
#   np.float64(0.7363096633436828),
#   np.float64(0.9463822160089359)],
#  ['svr', np.float64(0.7642079133544131), np.float64(0.8472636473483939)],
#  ['ridge', np.float64(0.7363125343993555), np.float64(0.9463387741853386)],
#  ['LASSO', np.float64(0.05943378064493573), np.float64(1.528905986892753)],
#  ['decision tree',
#   np.float64(0.775217252251678),
#   np.float64(0.7469113957667736)],
#  ['random forest',
#   np.float64(0.8813455991845821),
#   np.float64(0.5301907443828737)],
#  ['extra trees',
#   np.float64(0.8678662889822295),
#   np.float64(0.5544991797153718)],
#  ['gradient boosting',
#   np.float64(0.8725149176086591),
#   np.float64(0.5756213881409791)],
#  ['adaboost', np.float64(0.7543209334994885), np.float64(0.8131068025470256)],
#  ['mlp', np.float64(0.8035478428639736), np.float64(0.6751334323606777)],
#  ['xgboost', np.float64(0.8894876835260124), np.float64(0.5040475180464287)]]

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.889488  0.504048
# 5       random forest  0.881346  0.530191
# 6         extra trees  0.867866  0.554499
# 7   gradient boosting  0.872515  0.575621
# 9                 mlp  0.803548  0.675133
# 4       decision tree  0.775217  0.746911
# 8            adaboost  0.754321  0.813107
# 1                 svr  0.764208  0.847264
# 2               ridge  0.736313  0.946339
# 0          linear_reg  0.736310  0.946382
# 3               LASSO  0.059434  1.528906

# %% [markdown]
# ### OneHotEncoding

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first'),['sector','agePossession','furnishing_type'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean()
# Out:
# np.float64(0.8546073013476256)

# %%
scores.std()
# Out:
# np.float64(0.015999826710187303)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['sector', 'agePossession',
#                                                    'furnishing_type'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# np.float64(0.6497593061775198)

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 6         extra trees  0.894470  0.472923
# 10            xgboost  0.895850  0.493456
# 5       random forest  0.890796  0.506349
# 9                 mlp  0.874502  0.512863
# 7   gradient boosting  0.876648  0.569919
# 0          linear_reg  0.854607  0.649759
# 2               ridge  0.854685  0.652823
# 4       decision tree  0.808499  0.697527
# 1                 svr  0.769741  0.834124
# 8            adaboost  0.750923  0.840331
# 3               LASSO  0.059434  1.528906

# %% [markdown]
# ### OneHotEncoding With PCA

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['sector','agePossession'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', PCA(n_components=9)),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean()
# Out:
# np.float64(0.7059216559695731)

# %%
scores.std()
# Out:
# np.float64(0.03832201287802145)

# %%
def scorer(model_name, model):
    output = []    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('pca', PCA(n_components=9)),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.836568  0.636580
# 6         extra trees  0.834310  0.637039
# 5       random forest  0.830371  0.644691
# 7   gradient boosting  0.818767  0.726624
# 9                 mlp  0.792546  0.792437
# 1                 svr  0.780267  0.830910
# 4       decision tree  0.664965  0.853639
# 8            adaboost  0.681708  0.945829
# 2               ridge  0.705923  1.004096
# 0          linear_reg  0.705922  1.004225
# 3               LASSO  0.059676  1.528739

# %% [markdown]
# ### Target Encoder

# %%
columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['agePossession']),
        ('target_enc', ce.TargetEncoder(), ['sector'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (np.float64(0.829521918225536), np.float64(0.018384463379122837))

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.904798  0.447518
# 5       random forest  0.900919  0.456739
# 6         extra trees  0.902216  0.461574
# 7   gradient boosting  0.888855  0.509855
# 4       decision tree  0.828360  0.554244
# 9                 mlp  0.852885  0.614347
# 8            adaboost  0.816378  0.686327
# 0          linear_reg  0.829522  0.713011
# 2               ridge  0.829536  0.713523
# 1                 svr  0.782917  0.818851
# 3               LASSO  0.059434  1.528906

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'regressor__n_estimators': [50, 100, 200, 300],
    'regressor__max_depth': [None, 10, 20, 30],
    'regressor__max_samples':[0.1, 0.25, 0.5, 1.0],
    'regressor__max_features': ['auto', 'sqrt']
}

# %%
columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['agePossession']),
        ('target_enc', ce.TargetEncoder(), ['sector'])
    ], 
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor())
])

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
search = GridSearchCV(pipeline, param_grid, cv=kfold, scoring='r2', n_jobs=-1, verbose=4)

# %%
search.fit(X, y_transformed)
# Out:
# Fitting 10 folds for each of 128 candidates, totalling 1280 fits
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s[CV 4/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
#
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# ...
# [CV 7/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.902 total time=   0.5s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.912 total time=   0.9s
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
# [CV 7/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.897 total time=   0.9s
# [CV 2/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.923 total time=   0.9s
# [CV 7/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.902 total time=   0.9s
# [CV 4/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.894 total time=   0.4s
# [CV 8/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.895 total time=   0.4s
# [CV 1/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.912 total time=   0.9s
# [CV 4/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.895 total time=   0.8s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.886 total time=   1.3s
# [CV 8/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.893 total time=   0.8s
# [CV 8/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.897 total time=   0.8s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.906 total time=   0.9s
# [CV 2/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.931 total time=   1.2s
# [CV 2/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.930 total time=   0.8s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.911 total time=   1.2s
# [CV 4/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.898 total time=   1.2s
# [CV 1/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.912 total time=   1.3s
# [CV 5/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.906 total time=   0.8s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.889 total time=   0.8s
# [CV 4/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.890 total time=   0.9s
# [CV 5/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.906 total time=   1.2s
# [CV 6/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.893 total time=   1.2s
# [CV 6/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.894 total time=   0.8s
# [CV 8/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.897 total time=   1.1s
# [CV 7/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.902 total time=   1.2s
# [CV 10/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.887 total time=   0.7s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.887 total time=   1.1s
# [CV 10/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.889 total time=   1.1s
# /Users/daksh/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 640 fits failed out of a total of 1280.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 359 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 473, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 281 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 473, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/daksh/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.86862461 0.87192619
#  0.87152628 0.87284607 0.88458028 0.88664885 0.88760572 0.88847599
#  0.89460291 0.89628482 0.89678324 0.89681299 0.89796438 0.90090434
#  0.90239416 0.90180243        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.86823712 0.87092671 0.87034836 0.87155561 0.88077171 0.882999
#  0.88432593 0.88407345 0.88774569 0.88940772 0.88996555 0.89053064
#  0.89165745 0.8933591  0.89358695 0.89347126        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.86875134 0.8707153  0.87170059 0.87304639
#  0.88493643 0.88640704 0.88870322 0.88738919 0.89490808 0.89381741
#  0.89660029 0.89731252 0.89871619 0.90143523 0.90214358 0.90228293
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.86981311 0.87107981
#  0.87333415 0.87325108 0.88619674 0.88704533 0.88860218 0.88758177
#  0.89539907 0.89535216 0.89627435 0.89730481 0.90031586 0.90154334
#  0.90243294 0.90250253]
#   warnings.warn(
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['bedRoom',
#                                                                           'bathroom',
#                                                                           'built_up_area',
#                                                                           'servant '
#                                                                           'room',
#                                                                           'store '
#                                                                           'room']),
#                                                                         ('cat',
#                                                                          OrdinalEncoder(),
#                                                                          ['property_type',
#                                                                           'sector',
#                                                                           'balcony',
#                                                                           'agePossession',
#                                                                           'furnishing_type',...
#                                                                          OneHotEncoder(drop='first',
#                                                                                        sparse_output=False),
#                                                                          ['agePossession']),
#                                                                         ('target_enc',
#                                                                          TargetEncoder(),
#                                                                          ['sector'])])),
#                                        ('regressor', RandomForestRegressor())]),
#              n_jobs=-1,
#              param_grid={'regressor__max_depth': [None, 10, 20, 30],
#                          'regressor__max_features': ['auto', 'sqrt'],
#                          'regressor__max_samples': [0.1, 0.25, 0.5, 1.0],
#                          'regressor__n_estimators': [50, 100, 200, 300]},
#              scoring='r2', verbose=4)

# %%
final_pipe = search.best_estimator_

# %%
search.best_params_
# Out:
# {'regressor__max_depth': 30,
#  'regressor__max_features': 'sqrt',
#  'regressor__max_samples': 1.0,
#  'regressor__n_estimators': 300}

# %%
search.best_score_
# Out:
# np.float64(0.9025025308911081)

# %%
final_pipe.fit(X,y_transformed)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['agePossession']),
#                                                  ('target_enc', TargetEncoder(),
#                                                   ['sector'])])),
#                 ('regressor',
#                  RandomForestRegressor(max_depth=30, max_features='sqrt',
#                                        max_samples=1.0, n_estimators=300))])

# %%
# Define your columns to encode
columns_to_encode = ['property_type', 'sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1', OneHotEncoder(drop='first', sparse_output=False), ['agePossession']),
        ('target_enc', ce.TargetEncoder(), ['sector'])
    ], 
    remainder='passthrough'
)

# %%
# Create a pipeline with XGBRegressor
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', XGBRegressor(tree_method="hist", device="cuda"))
])

# Define the parameter grid for XGBRegressor
param_grid = {
    'regressor__n_estimators': [300, 500],
    'regressor__max_depth': [5, 10, 13],
    'regressor__learning_rate': [0.01, 0.1, 0.3],
    'regressor__gamma': [0, 0.1, 0.3],
    'regressor__subsample': [0.7, 1.0],  # Adjusted subsample values
    'regressor__colsample_bytree': [0.7, 1.0],
    'regressor__lambda': [0.1, 1],  # Regularization parameter
    'regressor__alpha': [0.1, 1]  # L1 regularization parameter
}

# Set up KFold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Perform grid search using GridSearchCV
search = GridSearchCV(pipeline, param_grid, cv=kfold, scoring='r2', n_jobs=-1, verbose=4)

# Assuming X and y_transformed are defined and compatible
search.fit(X, y_transformed)
# Out:
# Fitting 5 folds for each of 864 candidates, totalling 4320 fits
# [CV 1/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.903 total time=   0.3s
# [CV 2/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.886 total time=   0.2s
# [CV 3/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.882 total time=   0.2s
# [CV 4/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.889 total time=   0.2s
# [CV 5/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.876 total time=   0.2s
# [CV 1/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.906 total time=   0.2s
# [CV 5/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.886 total time=   0.3s
# [CV 2/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.900 total time=   0.3s
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeErrorAttributeError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# : _ARRAY_API not found
# AttributeError
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError_ARRAY_API not found: : _ARRAY_API not found
#
# AttributeError: _ARRAY_API not found_ARRAY_API not foundAttributeError
# : _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/daksh/anaconda3/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/__init__.py", line 9, in <module>
#     from category_encoders.backward_difference import BackwardDifferenceEncoder
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/category_encoders/backward_difference.py", line 3, in <module>
#     from patsy.contrasts import Diff, ContrastMatrix
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/__init__.py", line 77, in <module>
#     import patsy.highlevel
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/highlevel.py", line 19, in <module>
#     from patsy.design_info import DesignMatrix, DesignInfo
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/design_info.py", line 31, in <module>
#     from patsy.util import atleast_2d_column_default
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/patsy/util.py", line 33, in <module>
#     import pandas
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/daksh/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/daksh/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
# AttributeError: _ARRAY_API not found
# [CV 3/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.893 total time=   0.3s
# [CV 4/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.901 total time=   0.3s
# [CV 3/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.881 total time=   0.1s
# [CV 5/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.876 total time=   0.1s
# [CV 2/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.886 total time=   0.2s
# [CV 4/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.890 total time=   0.2s
# [CV 2/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.902 total time=   0.2s
# [CV 1/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.915 total time=   0.2s
# [CV 1/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.916 total time=   0.2s
# [CV 3/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.893 total time=   0.2s
# [CV 4/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.900 total time=   0.2s
# [CV 5/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.886 total time=   0.3s
# [CV 3/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.897 total time=   0.7s
# [CV 1/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.915 total time=   0.7s
# [CV 2/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.890 total time=   0.7s
# [CV 4/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.896 total time=   0.7s
# [CV 5/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.892 total time=   0.7s
# [CV 2/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.885 total time=   0.8s
# [CV 4/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.895 total time=   0.8s
# [CV 1/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.915 total time=   0.8s
# [CV 3/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.896 total time=   0.8s
# [CV 5/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.889 total time=   0.9s
# [CV 3/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.906 total time=   1.3s
# [CV 2/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.900 total time=   1.3s
# [CV 1/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.923 total time=   1.3s
# [CV 4/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.904 total time=   1.3s
# [CV 5/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.899 total time=   1.3s
# [CV 3/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.905 total time=   1.4s
# [CV 2/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.896 total time=   1.5s
# [CV 1/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.921 total time=   1.5s
# [CV 4/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.902 total time=   1.5s
# [CV 5/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.896 total time=   1.4s
# [CV 3/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.897 total time=   0.9s
# [CV 1/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.915 total time=   1.0s
# [CV 4/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.895 total time=   1.0s
# [CV 2/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.889 total time=   1.0s
# [CV 5/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.892 total time=   1.0s
# [CV 1/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.915 total time=   1.1s
# [CV 2/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.883 total time=   1.0s
# [CV 3/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.895 total time=   1.1s
# [CV 4/5] END regressor__alpha=0.1, regressor__colsample_bytree=0.7, regressor__gamma=0, regressor__lambda=0.1, regressor__learning_rate=0.01, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.892 total time=   1.1s
# ...
# [CV 3/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.1, regressor__max_depth=13, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.884 total time=   0.1s
# [CV 2/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.1, regressor__max_depth=13, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.894 total time=   0.1s
# [CV 5/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.1, regressor__max_depth=13, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.870 total time=   0.1s
# [CV 1/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.1, regressor__max_depth=13, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.904 total time=   0.1s
# [CV 2/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.886 total time=   0.1s
# [CV 1/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.899 total time=   0.1s
# [CV 3/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.885 total time=   0.1s
# [CV 4/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.888 total time=   0.1s
# [CV 2/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.888 total time=   0.1s
# [CV 1/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.901 total time=   0.1s
# [CV 4/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.891 total time=   0.1s
# [CV 3/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.883 total time=   0.1s
# [CV 5/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.871 total time=   0.1s
# [CV 5/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.865 total time=   0.1s
# [CV 5/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.867 total time=   0.1s
# [CV 3/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.880 total time=   0.1s
# [CV 4/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.880 total time=   0.2s
# [CV 3/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.885 total time=   0.2s
# [CV 5/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.862 total time=   0.2s
# [CV 2/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.898 total time=   0.2s
# [CV 1/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.901 total time=   0.1s
# [CV 1/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.902 total time=   0.1s
# [CV 2/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.893 total time=   0.2s
# [CV 4/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=5, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.882 total time=   0.2s
# [CV 3/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.885 total time=   0.1s
# [CV 2/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.888 total time=   0.1s
# [CV 1/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.901 total time=   0.1s
# [CV 1/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.901 total time=   0.1s
# [CV 4/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.888 total time=   0.1s
# [CV 3/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.885 total time=   0.1s
# [CV 4/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.888 total time=   0.1s
# [CV 5/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.871 total time=   0.1s
# [CV 2/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.888 total time=   0.1s
# [CV 5/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.872 total time=   0.1s
# [CV 4/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.880 total time=   0.1s
# [CV 3/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.880 total time=   0.1s
# [CV 5/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.867 total time=   0.1s
# [CV 1/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.901 total time=   0.1s
# [CV 3/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.880 total time=   0.1s
# [CV 5/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.867 total time=   0.1s
# [CV 2/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.896 total time=   0.1s
# [CV 1/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.901 total time=   0.1s
# [CV 4/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=10, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.880 total time=   0.1s
# [CV 2/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=300, regressor__subsample=0.7;, score=0.898 total time=   0.1s
# [CV 3/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.885 total time=   0.1s
# [CV 2/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.896 total time=   0.1s
# [CV 1/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.901 total time=   0.1s
# [CV 1/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.901 total time=   0.1s
# [CV 2/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.888 total time=   0.1s
# [CV 3/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.880 total time=   0.1s
# [CV 4/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.888 total time=   0.1s
# [CV 5/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.872 total time=   0.1s
# [CV 4/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=500, regressor__subsample=0.7;, score=0.880 total time=   0.1s
# [CV 5/5] END regressor__alpha=1, regressor__colsample_bytree=1.0, regressor__gamma=0.3, regressor__lambda=1, regressor__learning_rate=0.3, regressor__max_depth=13, regressor__n_estimators=500, regressor__subsample=1.0;, score=0.867 total time=   0.1s
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['bedRoom',
#                                                                           'bathroom',
#                                                                           'built_up_area',
#                                                                           'servant '
#                                                                           'room',
#                                                                           'store '
#                                                                           'room']),
#                                                                         ('cat',
#                                                                          OrdinalEncoder(),
#                                                                          ['property_type',
#                                                                           'sector',
#                                                                           'balcony',
#                                                                           'agePossession',
#                                                                           'furnishing_type',
#                                                                           '...
#                                                      num_parallel_tree=None,
#                                                      random_state=None, ...))]),
#              n_jobs=-1,
#              param_grid={'regressor__alpha': [0.1, 1],
#                          'regressor__colsample_bytree': [0.7, 1.0],
#                          'regressor__gamma': [0, 0.1, 0.3],
#                          'regressor__lambda': [0.1, 1],
#                          'regressor__learning_rate': [0.01, 0.1, 0.3],
#                          'regressor__max_depth': [5, 10, 13],
#                          'regressor__n_estimators': [300, 500],
#                          'regressor__subsample': [0.7, 1.0]},
#              scoring='r2', verbose=4)

# %%
search.best_params_
# Out:
# {'regressor__alpha': 0.1,
#  'regressor__colsample_bytree': 0.7,
#  'regressor__gamma': 0,
#  'regressor__lambda': 0.1,
#  'regressor__learning_rate': 0.1,
#  'regressor__max_depth': 5,
#  'regressor__n_estimators': 500,
#  'regressor__subsample': 1.0}

# %%
search.best_score_
# Out:
# np.float64(0.9076690291035117)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
final_pipe_xg = search.best_estimator_

# %%
final_pipe_xg.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse...
#                               enable_categorical=False, eval_metric=None,
#                               feature_types=None, gamma=0, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, lambda=0.1,
#                               learning_rate=0.1, max_bin=None,
#                               max_cat_threshold=None, max_cat_to_onehot=None,
#                               max_delta_step=None, max_depth=5, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=500, n_jobs=None, ...))])

# %%
y_pred = final_pipe_xg.predict(X_test)
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# np.float64(0.4594920825555858)

# %% [markdown]
# ### Exporting the model

# %%
final_pipe_xg.fit(X, y_transformed)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse...
#                               enable_categorical=False, eval_metric=None,
#                               feature_types=None, gamma=0, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, lambda=0.1,
#                               learning_rate=0.1, max_bin=None,
#                               max_cat_threshold=None, max_cat_to_onehot=None,
#                               max_delta_step=None, max_depth=5, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=500, n_jobs=None, ...))])

# %%
import pickle

with open('../pipeline.pkl', 'wb') as file:
    pickle.dump(final_pipe_xg, file)

# %%
with open('../df.pkl', 'wb') as file:
    pickle.dump(X, file)

# %%
X
# Out:
#      property_type      sector  bedRoom  bathroom balcony   agePossession  \
# 0             flat   sector 36      3.0       2.0       2    New Property
# 1             flat   sector 89      2.0       2.0       2    New Property
# 2             flat  sohna road      2.0       2.0       1    New Property
# 3             flat   sector 92      3.0       4.0      3+  Relatively New
# 4             flat  sector 102      2.0       2.0       1  Relatively New
# ...            ...         ...      ...       ...     ...             ...
# 3549          flat   sector 84      2.0       2.0       1  Relatively New
# 3550         house  sector 109      5.0       5.0      3+  Relatively New
# 3551          flat    sector 2      1.0       1.0       1  Moderately Old
# 3552         house   sector 43      5.0       6.0       3  Moderately Old
# 3553          flat   sector 68      3.0       3.0      3+  Relatively New
#
#       built_up_area  servant room  store room furnishing_type luxury_category  \
# 0             850.0           0.0         0.0     unfurnished             Low
# 1            1226.0           1.0         0.0     unfurnished             Low
# 2            1000.0           0.0         0.0     unfurnished             Low
# 3            1615.0           1.0         0.0   semifurnished            High
# 4             582.0           0.0         1.0     unfurnished            High
# ...             ...           ...         ...             ...             ...
# 3549          532.0           0.0         0.0     unfurnished          Medium
# 3550         6228.0           1.0         1.0     unfurnished            High
# 3551          665.0           0.0         0.0   semifurnished          Medium
# 3552         5490.0           1.0         1.0     unfurnished          Medium
# 3553         1845.0           0.0         0.0   semifurnished          Medium
#
#      floor_category
# 0         Low Floor
# 1         Mid Floor
# 2        High Floor
# 3         Mid Floor
# 4         Mid Floor
# ...             ...
# 3549      Mid Floor
# 3550      Low Floor
# 3551      Mid Floor
# 3552      Mid Floor
# 3553     High Floor
#
# [3554 rows x 12 columns]

# %% [markdown]
# ### Trying out the predictions

# %%
X.columns
# Out:
# Index(['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
#        'agePossession', 'built_up_area', 'servant room', 'store room',
#        'furnishing_type', 'luxury_category', 'floor_category'],
#       dtype='object')

# %%
X.iloc[0].values
# Out:
# array(['flat', 'sector 36', np.float64(3.0), np.float64(2.0), '2',
#        'New Property', np.float64(850.0), np.float64(0.0),
#        np.float64(0.0), 'unfurnished', 'Low', 'Low Floor'], dtype=object)

# %%
data = [['house', 'sector 102', 4, 3, '3+', 'New Property', 2750, 0, 0, 'unfurnished', 'Low', 'Low Floor']]
columns = ['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
       'agePossession', 'built_up_area', 'servant room', 'store room',
       'furnishing_type', 'luxury_category', 'floor_category']

# Convert to DataFrame
one_df = pd.DataFrame(data, columns=columns)

one_df
# Out:
#   property_type      sector  bedRoom  bathroom balcony agePossession  \
# 0         house  sector 102        4         3      3+  New Property
#
#    built_up_area  servant room  store room furnishing_type luxury_category  \
# 0           2750             0           0     unfurnished             Low
#
#   floor_category
# 0      Low Floor

# %%
np.expm1(final_pipe_xg.predict(one_df))
# Out:
# array([3.0049446], dtype=float32)
